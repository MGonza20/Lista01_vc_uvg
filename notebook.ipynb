# %% [markdown]
# # Lista 1

# %%
# Librerias necesarias

import cv2 as cv
import numpy as np
import os

from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# ## Inciso 1

# %% [markdown]
# ### OpenCV

# %%
# Leyendo imagen con OpenCV
img_opencv = cv.imread('imgs/saigon.jpeg', cv.IMREAD_COLOR)
img_opencv_rgb = cv.cvtColor(img_opencv, cv.COLOR_BGR2RGB) # convirtiendo de BGR a RGB

# Mostrando imagen
plt.imshow(img_opencv_rgb)
plt.axis('off')
plt.show()

# %%
# Almacenando imagen - OpenCV
dir_exists = cv.imwrite('imgs/save/saigon_opencv.jpeg', img_opencv) # Almacenando imagen en formato JPG

if not dir_exists: 
    os.makedirs('imgs/save')
    cv.imwrite('imgs/save/saigon_opencv.jpeg', img_opencv)

# %%
# Almacenando imagen con Matplotlib
plt.imsave('imgs/save/saigon_matplotlib.png', img_opencv_rgb)

# %%
# Convertir a un array de numpy - OpenCV
img_opencv # En el caso de OpenCV, no es necesario porque la imagen se almacena en un array de numpy por defecto
# Out:
# array([[[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        ...,
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]]], dtype=uint8)

# %% [markdown]
# La imagen se almacena en memoria como un arreglo tridimensional de NumPy. La primera dimensión corresponde a la altura de la imagen, reflejando la cantidad de filas. Por otra parte, la segunda dimensión indica el ancho de la imagen, donde cada elemento dentro de una fila equivale a un píxel, cada uno se representa por un arreglo unidimensional, representando a la tercera dimensión. En este arreglo, se almacena la información de color de cada píxel siguiendo el formato BGR (Azul, Verde, Rojo).

# %% [markdown]
# ### PIL

# %%
# Leyendo imagen con PIL

img_pil = Image.open('imgs/saigon.jpeg')

# Mostrando imagen
img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1067>

# %%
# Almacenando imagen - PIL
img_pil.save('imgs/save/saigon_pil.jpeg') # Almacenando imagen en formato JPG

# Convertir a un array de numpy - PIL
img_pil_np = np.array(img_pil)
img_pil_np
# Out:
# array([[[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        ...,
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]],
#
#        [[3, 3, 3],
#         [3, 3, 3],
#         [3, 3, 3],
#         ...,
#         [2, 2, 2],
#         [2, 2, 2],
#         [2, 2, 2]]], dtype=uint8)

# %% [markdown]
# La imagen se almacena en memoria como un arreglo tridimensional. En este arreglo, se almacena la información de color de cada píxel siguiendo el formato RGB (Rojo, Verde, Azul).

# %% [markdown]
# ## Inciso 3
# ##### Implementar en Python una función que haga la ecualización de histograma para una imagen en escala de grises (8 bits).

# %%
from utils import plot_eq

# %%
img_opencv = cv.imread('imgs/low_contrast_img.jpeg', cv.IMREAD_COLOR)
img_escala_grises = cv.cvtColor(img_opencv, cv.COLOR_BGR2GRAY)
plot_eq(img_escala_grises)

# %%
plot_eq(img_escala_grises, True)

# %% [markdown]
# ### Con OpenCV

# %%
img_eq_opencv = cv.equalizeHist(img_escala_grises)
plot_eq(img = img_eq_opencv, opencv=True)

# %% [markdown]
# ### Inciso 3 - Prueba 2

# %%
img_opencv = cv.imread('imgs/monkey.jpeg', cv.IMREAD_COLOR)
img_escala_grises = cv.cvtColor(img_opencv, cv.COLOR_BGR2GRAY)
plot_eq(img_escala_grises)

# %%
plot_eq(img_escala_grises, True)

# %% [markdown]
# ### Con OpenCV

# %%
img_eq_opencv = cv.equalizeHist(img_escala_grises)
plot_eq(img = img_eq_opencv, opencv=True)

# %% [markdown]
# ## Resultados
# Los resultados son los mismos.
